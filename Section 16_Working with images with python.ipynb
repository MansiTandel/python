# %%
# working with images
# Pillow Library
# PIL- Python imaging library

# %%
import PIL

# %%
from PIL import Image

# %%
pic1=Image.open("lets-do-it.webp")

# %%
pic1
# Out:
# <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=800x569 at 0x244E8296640>

# %%
type(pic1)
# Out:
# PIL.WebPImagePlugin.WebPImageFile

# %%
pic1.size
# Out:
# (800, 569)

# %%
pic1.filename
# Out:
# 'lets-do-it.webp'

# %%
pic1.format_description
# Out:
# 'WebP image'

# %%
# CROPPING IMAGES

# %%
pic1.crop((0,0,100,100))
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x244ED1DA610>

# %%
pic1.size
# Out:
# (800, 569)

# %%
x=0
y=0

w=800/3
h=569/10

# %%
pic1.crop((x,y,w,h))
# Out:
# <PIL.Image.Image image mode=RGB size=267x57 at 0x244ED7003D0>

# %%
halfway = 800/2

# %%
x=halfway-200
w=halfway+200

# %%
y= 100
h= 300

# %%
pic1.crop((x,y,w,h))
# Out:
# <PIL.Image.Image image mode=RGB size=67x200 at 0x244EE3243D0>

# %%
pic2=pic1.crop((x,y,w,h))

# %%
pic1.paste(im=pic2,box=(0,0))

# %%
pic1
# Out:
# <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=800x569 at 0x244E8296640>

# %%
pic1.size
# Out:
# (800, 569)

# %%
pic1.resize((200,256))
# Out:
# <PIL.Image.Image image mode=RGB size=200x256 at 0x244EE33D5E0>

# %%
pic1.rotate(90)
# Out:
# <PIL.Image.Image image mode=RGB size=800x569 at 0x244ED984B80>

# %%
# COLOR TRANSPARENCY


# RGBA

# %%
red = Image.open("red_color.jpg")

# %%
red
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=200x200 at 0x244EDA20B20>

# %%
blue=Image.open("blue_color.png")

# %%
blue
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=200x200 at 0x244EDC8F370>

# %%
#red.putalpha(23)

# %%
red
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=200x200 at 0x244EDA20B20>

# %%
blue
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=200x200 at 0x244EDC8F370>

# %%
blue.paste(im=red,box=(0,0),mask=red)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [129], in <cell line: 1>()
# ----> 1 blue.paste(im=red,box=(0,0),mask=red)
#
# File ~\Anaconda3\lib\site-packages\PIL\Image.py:1557, in Image.paste(self, im, box, mask)
#    1555 if mask:
#    1556     mask.load()
# -> 1557     self.im.paste(im, box, mask.im)
#    1558 else:
#    1559     self.im.paste(im, box)
#
# ValueError: bad transparency mask

# %%
blue
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=200x200 at 0x244EDC8F370>

# %%
im = Image.open("blue_color.png")
rgb_im = im.convert('RGB')
rgb_im.save('blue_color.jpg')
#Image.open('blue_color.png').convert('RGB').save('blue_new.jpg')"

# %%
rgb_im
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x244EDC7A1C0>

# %%
rgb_im.paste(im=red,box=(0,0),mask=red)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [139], in <cell line: 1>()
# ----> 1 rgb_im.paste(im=red,box=(0,0),mask=red)
#
# File ~\Anaconda3\lib\site-packages\PIL\Image.py:1557, in Image.paste(self, im, box, mask)
#    1555 if mask:
#    1556     mask.load()
# -> 1557     self.im.paste(im, box, mask.im)
#    1558 else:
#    1559     self.im.paste(im, box)
#
# ValueError: bad transparency mask

# %%
rgb_im
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x244EDC7A1C0>
